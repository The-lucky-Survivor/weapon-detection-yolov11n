# %%
# !yolo export model=runs1/detect/train/weights/best.pt format=tflite imgsz=640
# Out:
# Ultralytics 8.3.235  Python-3.11.7 torch-2.1.0+cpu CPU (13th Gen Intel Core i5-1335U)
#  ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLO11n summary (fused): 100 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from 'runs1\detect\train\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 7, 8400) (5.2 MB)
# requirements: Ultralytics requirements ['tf_keras<=2.19.0', 'sng4onnx>=1.0.1', 'onnx_graphsurgeon>=0.3.26', 'ai-edge-litert>=1.2.0', 'onnx>=1.12.0,<=1.19.1', 'onnx2tf>=1.26.3', 'onnxslim>=0.1.71', 'onnxruntime'] not found, attempting AutoUpdate...
# ...

# %%
# !yolo export model=runs1/detect/train/weights/best.pt format=tflite imgsz=640
# Out:
# Ultralytics 8.3.235  Python-3.11.7 torch-2.1.0+cpu CPU (13th Gen Intel Core i5-1335U)
# YOLO11n summary (fused): 100 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from 'runs1\detect\train\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 7, 8400) (5.2 MB)
# requirements: Ultralytics requirements ['tf_keras<=2.19.0', 'sng4onnx>=1.0.1', 'ai-edge-litert>=1.2.0'] not found, attempting AutoUpdate...
# WARNING Retry 1/2 failed: Command 'pip install --no-cache-dir "tf_keras<=2.19.0" "sng4onnx>=1.0.1" "ai-edge-litert>=1.2.0" --extra-index-url https://pypi.ngc.nvidia.com' returned non-zero exit status 1.
# WARNING Retry 2/2 failed: Command 'pip install --no-cache-dir "tf_keras<=2.19.0" "sng4onnx>=1.0.1" "ai-edge-litert>=1.2.0" --extra-index-url https://pypi.ngc.nvidia.com' returned non-zero exit status 1.
# ...
